# %%
# The next logical step is to deal with handling user input. When a player (say player 1, who is X) wants to place an X on the screen, they can’t just click on a terminal. So we are going to approximate this clicking simply by asking the user for a coordinate of where they want to place their piece.
# The computer asks Player 1 (X) what their move is (in the format row,col), and say they type 1,3. Then the game would print out
# game =
       [[0, 0, X],
    	[0, 0, 0],
    	[0, 0, 0]]
# And ask Player 2 for their move, printing an O in that place.
# Things to note:
    # For this exercise, assume that player 1 (the first player to move) will always be X and player 2 (the second player) will always be O.
    # Ask the user to enter coordinates in the form “row,col” - a number, then a comma, then a number. Then you can use your Python skills to figure out which row and column they want their piece to be in.
    # Don’t worry about checking whether someone won the game, but if a player tries to put a piece in a game position where there already is another piece, do not allow the piece to go there.

# Bonus:
    # For the “standard” exercise, don’t worry about “ending” the game - no need to keep track of how many squares are full. In a bonus version, keep track of how many squares are full and automatically stop asking for moves when there are no more valid moves.

# %%
list1 = [0,0,0]
list2 = [0,0,0]
list3 = [0,0,0]

game = [list1, 
        list2,
        list3]

possible_moves = ["1,1", "1,2", "1,3", "2,1", "2,2", "2,3", "3,1", "3,2", "3,3"]
turn = "Player 1"

while True:
    if len(possible_moves) == 0:
        print("End of the game")
        break

            
    if turn == "Player 1":
        print("\nPlayer 1 turn. Please enter coordinates where do you want to place an X.\nPossible moves are:", end = "   ")
        for i in range(len(possible_moves)):
            print (possible_moves[i], end = "   ")
        move = input("\n")
        if move not in possible_moves:
            continue
        else:
            possible_moves.remove(move)
            game[int(move[0])-1][int(move[2])-1] = 1
            turn = "Player 2"
            
    if len(possible_moves) == 0:
        print("End of the game")
        break
            
    if turn == "Player 2":
        print("\nPlayer 2 turn. Please enter coordinates where do you want to place an O.\nPossible moves are:", end = "   ")
        for i in range(len(possible_moves)):
            print (possible_moves[i], end = "   ")
        move = input("\n")
        if move not in possible_moves:
            continue
        else:
            possible_moves.remove(move)
            game[int(move[0])-1][int(move[2])-1] = 20
            turn = "Player 1"
# Out:
# Player 1 turn. Please enter coordinates where do you want to place an X.
# Possible moves are:   1,1   1,2   1,3   2,1   2,2   2,3   3,1   3,2   3,3
# 1,3
#
# Player 2 turn. Please enter coordinates where do you want to place an O.
# Possible moves are:   1,1   1,2   2,1   2,2   2,3   3,1   3,2   3,3
# 2,1
#
# Player 1 turn. Please enter coordinates where do you want to place an X.
# Possible moves are:   1,1   1,2   2,2   2,3   3,1   3,2   3,3
# 3,2
#
# Player 2 turn. Please enter coordinates where do you want to place an O.
# Possible moves are:   1,1   1,2   2,2   2,3   3,1   3,3
# 1,1
#
# Player 1 turn. Please enter coordinates where do you want to place an X.
# Possible moves are:   1,2   2,2   2,3   3,1   3,3
# 1,2
#
# Player 2 turn. Please enter coordinates where do you want to place an O.
# Possible moves are:   2,2   2,3   3,1   3,3
# 2,3
#
# Player 1 turn. Please enter coordinates where do you want to place an X.
# Possible moves are:   2,2   3,1   3,3
# 3,3
#
# Player 2 turn. Please enter coordinates where do you want to place an O.
# Possible moves are:   2,2   3,1
# 2,2
#
# Player 1 turn. Please enter coordinates where do you want to place an X.
# Possible moves are:   3,1
# 3,1
# End of the game
